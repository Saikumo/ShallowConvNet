# %%
from common import set_seed
from kfold.train_kfold import *

set_seed()
train_all_kfold()
# Out:
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Fold 1, Epoch 1/100 | Train Loss: 1.4866 Acc: 0.257 | Val Loss: 2.7756 Acc: 0.241
# Fold 1, Epoch 2/100 | Train Loss: 1.1859 Acc: 0.470 | Val Loss: 2.4474 Acc: 0.190
# Fold 1, Epoch 3/100 | Train Loss: 0.9902 Acc: 0.583 | Val Loss: 2.6096 Acc: 0.172
# Fold 1, Epoch 4/100 | Train Loss: 0.8410 Acc: 0.678 | Val Loss: 2.3415 Acc: 0.207
# Fold 1, Epoch 5/100 | Train Loss: 0.7066 Acc: 0.735 | Val Loss: 1.7957 Acc: 0.207
# Fold 1, Epoch 6/100 | Train Loss: 0.5960 Acc: 0.804 | Val Loss: 1.2489 Acc: 0.362
# ...
